# %% [markdown]
# Notebook for training a regression model on the cleaned fortune 1000 dataset in order to try to predict company profits.

# %%
#import required modules

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error, 
    r2_score)

# %%
df = pd.read_csv('fortune1000_cleaned.csv',encoding='latin1')
df = df.dropna()
print(df.columns)
# Out:
# Index(['rank', 'title', 'Previous Rank', 'Revenues ($M)', 'Revenue Change %',
#        'Profits ($M)', 'Profit Change %', 'Assets ($M)',
#        'Mkt Value as of 3/29/18 ($M)', 'Employees', 'Rank increase'],
#       dtype='str')

# %%
#create model
model = LinearRegression()


#define label and features
x = df[['Rank increase', 'Revenues ($M)', 'Revenue Change %', 'Employees','Mkt Value as of 3/29/18 ($M)' ]]
y = df['Profits ($M)']

#split data into training and testing sets

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

#train model on training sets
model = model.fit(x_train,y_train)

print(model.coef_)
print(model.intercept_)
# Out:
# [ 2.82990669e+00  4.65056459e-02 -1.78656269e+01 -5.49126511e-03
#   2.86813405e-02]
# 169.14601799432535

# %%
#Make predictions and compare

predictions = model.predict(x_test)

mae = mean_absolute_error(y_test, predictions)
print(mae)

mse = mean_squared_error(y_test, predictions)
print(mse)

rmse = np.sqrt(mse)
print(rmse)

r2 = r2_score(y_test, predictions)
# Out:
# 936.5560169316733
# 7290865.703839734
# 2700.1603107667024

# %%
#create summary table of predictions
results = pd.DataFrame({"Metric": ["MAE", "MSE", "RMSE", "R2"],"Value": [mae, mse, rmse, r2]})

print(results)

#make latex table

latex_table = results.to_latex(index=False, float_format="%.3f")
print(latex_table)
# Out:
#   Metric         Value
# 0    MAE  9.365560e+02
# 1    MSE  7.290866e+06
# 2   RMSE  2.700160e+03
# 3     R2  6.423160e-01
# \begin{tabular}{lr}
# \toprule
# Metric & Value \\
# \midrule
# MAE & 936.556 \\
# MSE & 7290865.704 \\
# RMSE & 2700.160 \\
# R2 & 0.642 \\
# \bottomrule
# \end{tabular}
